# %% [markdown]
# # Create Tiles for Indonesia Coastline

# %%
import os

import geopandas as gpd
import pandas as pd
from odc.geo import BoundingBox
from ipyleaflet import basemaps

from coastlines.grids import INDONESIA_25, INDONESIA_10, INDONESIA_CRS

from odc.geo.gridspec import GridSpec

os.environ["USE_PYGEOS"] = "0"

# %% [markdown]
# ## Shows which coastlines.grids library is imported

# %%
import coastlines.grids
print(coastlines.grids.__file__)
# Out:
# /opt/conda/lib/python3.12/site-packages/coastlines/grids.py

# %% [markdown]
# It looks like the imported libraries are not from this repository, so we need to define the grid in this notebook and take some parameters from the existing grids.
# First shows grid parameters.

# %%
print('INDONESIA_25:', INDONESIA_25, INDONESIA_25.origin)
print('INDONESIA_10:', INDONESIA_10, INDONESIA_10.origin)
print('INDONESIA_CRS:', INDONESIA_CRS)
# Out:
# INDONESIA_25: GridSpec(crs=EPSG:3832, tile_shape=Shape2d(x=2000, y=2000), resolution=Resolution(x=25, y=-25)) XY(x=-6250000, y=-1250000)
# INDONESIA_10: GridSpec(crs=EPSG:3832, tile_shape=Shape2d(x=5000, y=5000), resolution=Resolution(x=10, y=-10)) XY(x=-6250000, y=-1250000)
# INDONESIA_CRS: EPSG:3832

# %% [markdown]
# ## Create Indonesia 10 km tiles
#
# Create new Indonesia grid with 10 km tiles using GridSpec

# %%
INDONESIA_10KM = GridSpec(
    crs='ESRI:54034', # Cylindrical Equal Area
    tile_shape=(5000, 5000),
    resolution=2,
    origin=INDONESIA_25.origin,
)
print('INDONESIA_10KM:', INDONESIA_10KM, INDONESIA_10KM.origin)
# Out:
# INDONESIA_10KM: GridSpec(crs=ESRI:54034, tile_shape=Shape2d(x=5000, y=5000), resolution=Resolution(x=2, y=-2)) XY(x=-6250000, y=-1250000)

# %% [markdown]
# Create tiles with INDONESIA_10KM grid specs

# %%
# Select relevant tiles and convert to Geopandas
bounds = BoundingBox(94, -11, 142, 6, crs='EPSG:4326').to_crs(INDONESIA_10KM.crs)
geom = INDONESIA_10KM.geojson(bbox=bounds)
tiles_projected_10km = gpd.GeoDataFrame.from_features(geom, crs='EPSG:4326').to_crs(
    INDONESIA_10KM.crs
)

# %% [markdown]
# ## Indonesia coast tiles
#
# Read Indonesia's 5K coastline

# %%
idn_coastline = gpd.read_file('../data/raw/GARISPANTAI_5K_SEPT2024.gdb')

# %% [markdown]
# Check if Indonesia 10km tiles has the same CRS as the coastline data

# %%
if tiles_projected_10km.crs != idn_coastline.crs:
    print(f'Reproject tiles to {idn_coastline.crs}') 
    tiles_idn = tiles_projected_10km.to_crs(crs=str(idn_coastline.crs).upper())
else:
    print('Same CRS')
    tiles_idn = tiles_projected_10km.copy()
# Out:
# Reproject tiles to EPSG:4326

# %% [markdown]
# Perform spatial join: tiles that intersect any coastline segment. Tiles id column merged into the table.

# %%
# Perform spatial join: tiles that intersect any coastline segment
tiles_idn_coast = gpd.sjoin(tiles_idn, idn_coastline, predicate="intersects", how="inner")
tiles_idn_coast.head(3)
# Out:
#                                               geometry     idx  index_right  \
# 321  POLYGON ((122.7997 -10.91663, 122.7997 -11.008...  1992,4        34112
# 321  POLYGON ((122.7997 -10.91663, 122.7997 -11.008...  1992,4        33889
# 321  POLYGON ((122.7997 -10.91663, 122.7997 -11.008...  1992,4        34113
#
#            NAMOBJ       FCODE         REMARK METADATA SRS_ID  DTMVER  ELEVAS  \
# 321  Garis Pantai  DB02080140  Digitasi - FU            4326     NaN     NaN
# 321  Garis Pantai  DB02080140  Digitasi - FU            4326     NaN     NaN
# 321  Garis Pantai  DB02080140  Digitasi - FU            4326     NaN     NaN
#
#      KARGPN  TIPGPN KODGPN  THNSBDATA  SBDATA  SKL THNPBL KET    Panjang  \
# 321     5.0       4         2011-2014     6.0    4   2024      12.584924
# 321     3.0       4         2011-2014     6.0    4   2024       0.331914
# 321     3.0       4         2011-2014     6.0    4   2024       0.791579
#
#      Shape_Length
# 321      0.113479
# 321      0.002994
# 321      0.007135

# %% [markdown]
# Keep unique tiles only. Removing redundant tiles and unnecessary columns.

# %%
# Keep unique tiles only
tiles_idn_coast = tiles_idn.loc[tiles_idn.index.isin(tiles_idn_coast.index)]
tiles_idn_coast.head(3)
# Out:
#                                               geometry     idx
# 321  POLYGON ((122.7997 -10.91663, 122.7997 -11.008...  1992,4
# 322  POLYGON ((122.88953 -10.91663, 122.88953 -11.0...  1993,4
# 323  POLYGON ((122.97936 -10.91663, 122.97936 -11.0...  1994,4

# %% [markdown]
# Filtered tiles based on coastline data.

# %%
tiles_idn_coast.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ba5ff65f9bdc5d1cf2ed02f79392fd3f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ba5ff65f9bdc5d1cf2ed02f79392fd3f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ba5ff65f9bdc5d1cf2ed02f79392fd3f = L.map(
#                 &quot;map_ba5ff65f9bdc5d1cf2ed02f79392fd3f&quot;,
#                 {
#                     center: [-2.469188242572142, 117.99371256909913],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_ba5ff65f9bdc5d1cf2ed02f79392fd3f);
#
#
#
#
#
#             var tile_layer_d0b1a32ad2c4e823b16e9bffc036733e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d0b1a32ad2c4e823b16e9bffc036733e.addTo(map_ba5ff65f9bdc5d1cf2ed02f79392fd3f);
#
#
#             map_ba5ff65f9bdc5d1cf2ed02f79392fd3f.fitBounds(
#                 [[-11.00869953704888, 94.95192553143342], [6.070323051904596, 141.03549960676486]],
#                 {}
#             );
#
#
#         function geo_json_06c46f3cdbfd620a2692c072e02babf3_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_06c46f3cdbfd620a2692c072e02babf3_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_06c46f3cdbfd620a2692c072e02babf3_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_06c46f3cdbfd620a2692c072e02babf3_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_06c46f3cdbfd620a2692c072e02babf3_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_06c46f3cdbfd620a2692c072e02babf3.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_06c46f3cdbfd620a2692c072e02babf3_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_06c46f3cdbfd620a2692c072e02babf3 = L.geoJson(null, {
#                 onEachFeature: geo_json_06c46f3cdbfd620a2692c072e02babf3_onEachFeature,
#
#                 style: geo_json_06c46f3cdbfd620a2692c072e02babf3_styler,
#                 pointToLayer: geo_json_06c46f3cdbfd620a2692c072e02babf3_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_06c46f3cdbfd620a2692c072e02babf3_add (data) {
#             geo_json_06c46f3cdbfd620a2692c072e02babf3
#                 .addData(data);
#         }
#             geo_json_06c46f3cdbfd620a2692c072e02babf3_add({&quot;bbox&quot;: [94.95192553143342, -11.00869953704888, 141.03549960676486, 6.070323051904596], &quot;features&quot;: [{&quot;bbox&quot;: [122.79969933913857, -11.00869953704888, 122.8895308675505, -10.916626145714877], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[122.79969933913857, -10.916626145714877], [122.79969933913857, -11.00869953704888], [122.8895308675505, -11.00869953704888], [122.8895308675505, -10.916626145714877

# %%
# Export the results as Geopackage and GeoJSON
tiles_idn_coast = tiles_idn_coast.rename(columns={'idx': 'id'})
tiles_idn_coast.to_crs('EPSG:4326').to_file(
    '../data/raw/indonesia_10km_tiles_coast.geojson', driver='GeoJSON'
)
tiles_idn_coast.to_crs('EPSG:4326').to_file(
    '../data/raw/indonesia_10km_tiles_coast.gpkg', driver='GPKG'
)
